# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
import numpy as np
import scipy
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt

#primero creamos funciones para la distribución normal
def normal_pdf(x, mean, sigma):
    return norm.pdf(x, loc=mean, scale=sigma)
def normal_cdf(x, mean, sigma):
    return norm.cdf(x, mean, sigma)
def normal_ppf(p, mean, sigma):
    return norm.ppf(p, mean, sigma)
def normal_rvs(mean, sigma, size):
    return norm.rvs(loc=mean, scale=sigma, size=size)

print(f"PDF en una distribución normal con media=3 y desviación estándar= 2 en un valor de 4 es: {normal_pdf(4, mean=3, sigma=2)}")
print (f"CDF en distribución normal con media = 3 y desviación estándar = 2 en un valor de 4 es: {normal_cdf(4, mean=3, sigma=2)}")
print(f"Distribución normal con media = 3 y desviaciójn estándar = 2 con el perceptil 95%: {normal_ppf(0.95, mean=3, sigma=2)}")
print(f"Generar 100 valores random en una distribución normal con media=3 y desviación estándar=2:{normal_rvs(mean=3, sigma=2, size=100)}")

#Representamos las funciones anteriores
data = np.linspace(-10, 10, 100)
pdf = normal_pdf(data, mean=3, sigma=2)
cdf = normal_cdf(data, mean = 3, sigma=2)
ppf = normal_ppf(data, mean=3, sigma=2)

fig, axis = plt.subplots(3, 1, figsize = (5,7))

#¿cómo se crearían los gráficos?
axis[0].plot(data, pdf, label="PDF", color="red")
axis[1].plot(data, cdf, label="CDF", color="blue")
axis[2].plot(np.linspace(0, 1, 100), ppf, label="PPF", color="green")

plt.tight_layout()
plt.show()

#Distribución del valor min de 1 en una escala de 9
#Definición de las funciones de probabilidad relacionada con la distribución
def uniforme_pdf (x, loc, scale):
    return stats.uniform.pdf(x, loc, scale)
def uniforme_cdf (x, loc, scale):
    return stats.uniform.cdf(x, loc, scale)
def uniforme_ppf (q , loc, scale):
    return stats.uniform.ppf(q, loc, scale)
def variables_uniformes (loc, scale, size):
    return stats.uniform.rvs(loc, scale, size)

print (f"PDF en una distribución uniforme con loc =1 escala = 9 en un valor 4 es : {uniforme_cdf(4, loc=1, scale=9)}")
print (f" CDF en una distribución unforme con loc= 1 y escala=9 en valor 4 es: {uniforme_cdf(4, loc=1, scale=9)}")
print (f"Distribución unifrome con loc = 1 escala = 9 en un percentil 95 : {uniforme_ppf(0.95, loc=1, scale=9)}")
print (f" Generar 100 valores random en una distribución unifomre con loc=1 y escala=9 : {variables_uniformes(loc=1, scale=9, size=10)}")

#Representamos funciones anteriores
data = np.linspace(0, 10, 100)
pdf = uniforme_pdf(data, loc=1, scale=9)
cdf = uniforme_cdf(data, loc=1, scale=9)
ppf = uniforme_ppf(data, loc=1, scale=9)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "red")
axis[1].stem(data, cdf, "blue")
axis[2].stem(data, ppf, "green")

plt.tight_layout()
plt.show()
# Out:
# PDF en una distribución normal con media=3 y desviación estándar= 2 en un valor de 4 es: 0.17603266338214973
# CDF en distribución normal con media = 3 y desviación estándar = 2 en un valor de 4 es: 0.6914624612740131
# Distribución normal con media = 3 y desviaciójn estándar = 2 con el perceptil 95%: 6.289707253902945
# Generar 100 valores random en una distribución normal con media=3 y desviación estándar=2:[-2.9939303   6.71544214  3.42765893  6.50250313  4.43572913 -1.094181
#   3.96169806  1.98646568  1.13928867  2.71380561  3.40733916  1.73503524
#  -0.48057519  2.91081256  4.6551943   7.2333696   3.47838175  6.23681567
#   1.7589042   6.81378192  0.68220388  5.07136881  2.7552388   1.98006898
#   2.22684923  3.95141403  4.9677486   1.55535146  5.94550535  3.50182214
#   2.45334624  3.55615735  4.40355514  8.25548095  3.81425665  5.33738327
#   2.25118651  7.39471089  6.99669275  5.97537604  4.80260977  1.46234928
# ...
